# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv(r"D:\\DataScience\\seaborn-data-master\\bank_data.csv")

dataset.head(3)
# Out:
#    installment  int.rate  delinq.2yrs
# 0       829.10    0.1189            1
# 1       228.22    0.1071            0
# 2       366.86    0.1357            1

# %%
dataset.isnull().sum()
# Out:
# installment    0
# int.rate       0
# delinq.2yrs    0
# dtype: int64

# %%
sns.scatterplot(x="installment",y="int.rate",data=dataset,hue="delinq.2yrs")
plt.show()

# %%
x=dataset.iloc[:,:-1]
y=dataset["delinq.2yrs"]

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc= StandardScaler()
sc.fit(x)
x = pd.DataFrame(sc.transform(x),columns=x.columns)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier(n_neighbors=2)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
knn.score(x_test,y_test)*100
# Out:
# 53.125

# %%
knn.score(x_train,y_train)*100
# Out:
# 74.80314960629921

# %%
knn.predict([[829.10,0.1189]])
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
x
# Out:
#      installment  int.rate
# 0       3.932184  0.690928
# 1       0.035932  0.160172
# 2       0.934908  1.446580
# 3      -0.391249 -0.123198
# 4      -0.776543  1.756937
# ..           ...       ...
# 154     3.711784 -0.604477
# 155    -0.414009 -0.177173
# 156    -0.813633 -0.033239
# 157     0.267744  0.533500
# 158     1.179753  0.250130
#
# [159 rows x 2 columns]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 154    1
# 155    1
# 156    0
# 157    1
# 158    0
# Name: delinq.2yrs, Length: 159, dtype: int64

# %%
plot_decision_regions(x.to_numpy(),y.to_numpy(),clf=knn)
plt.show()
# Out:
# c:\Users\admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
for i in range(1,30):
    knn1= KNeighborsClassifier()
    knn1.fit(x_train,y_train)
    print(i,knn1.score(x_train,y_train)*100,knn1.score(x_test,y_test)*100)
# Out:
# 1 70.86614173228347 59.375
# 2 70.86614173228347 59.375
# 3 70.86614173228347 59.375
# 4 70.86614173228347 59.375
# 5 70.86614173228347 59.375
# 6 70.86614173228347 59.375
# 7 70.86614173228347 59.375
# 8 70.86614173228347 59.375
# 9 70.86614173228347 59.375
# 10 70.86614173228347 59.375
# 11 70.86614173228347 59.375
# 12 70.86614173228347 59.375
# 13 70.86614173228347 59.375
# 14 70.86614173228347 59.375
# 15 70.86614173228347 59.375
# 16 70.86614173228347 59.375
# 17 70.86614173228347 59.375
# 18 70.86614173228347 59.375
# 19 70.86614173228347 59.375
# 20 70.86614173228347 59.375
# 21 70.86614173228347 59.375
# 22 70.86614173228347 59.375
# 23 70.86614173228347 59.375
# 24 70.86614173228347 59.375
# 25 70.86614173228347 59.375
# 26 70.86614173228347 59.375
# 27 70.86614173228347 59.375
# 28 70.86614173228347 59.375
# 29 70.86614173228347 59.375
