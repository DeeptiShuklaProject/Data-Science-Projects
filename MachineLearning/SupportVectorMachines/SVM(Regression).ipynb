# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mlxtend.plotting import plot_decision_regions
from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv(r"D:\\DataScience\\seaborn-data-master\\anagrams.csv")

dataset.head(3)
# Out:
#    subidr    attnr  num1  num2  num3
# 0       1  divided     2   4.0     7
# 1       2  divided     3   4.0     5
# 2       3  divided     3   5.0     6

# %%
sns.scatterplot(x="num1",y="num2",data=dataset)
plt.show()

# %%
x=dataset[["num1"]]
y=dataset["num2"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.svm import SVR

# %%
sv=SVR(kernel="linear")
sv.fit(x_train,y_train)
# Out:
# SVR(kernel='linear')

# %%
# sv=SVR(kernel="poly")
# sv.fit(x_train,y_train)
# Out:
# SVR(kernel='poly')

# %%
sv.score(x_test,y_test)*100
# Out:
# 71.75000000000048

# %%
sv.score(x_train,y_train)*100
# Out:
# 63.17918590012571

# %%
sns.scatterplot(x="num1",y="num2",data=dataset)
plt.plot(dataset["num1"],sv.predict(x),color="red")
plt.show()
